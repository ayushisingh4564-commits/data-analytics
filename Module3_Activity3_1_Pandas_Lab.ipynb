# %% [markdown]
# <a href="https://colab.research.google.com/github/ayushisingh4564-commits/data-analytics/blob/main/Module3_Activity3_1_Pandas_Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Module 3 – Activity 3.1
# ## Pandas Hands-on Lab (5 Marks)
#
# **Instructions:**
# - Complete all tasks
# - Write code in the given cells
# - Run each cell and show outputs
# - Add comments wherever required
# - Submit the completed notebook (PDF) on LMS
#
# **Name:** Ayushi Kumari
# **Roll No.:** Betn1ai25234
# **Course:** Data Analytics Using Python (AIL0202)

# %%
# Import required libraries
# Write code to import pandas and numpy

# %% [markdown]
# ## Task 1: Data Creation & Loading (1 Mark)
# Dataset:
#     'Name': ['Aman','Riya','Rahul','Sneha','Karan'],
#     'Department': ['IT','HR','IT','Finance','HR'],
#     'Salary': [50000,60000,55000,65000,52000]

# %%
# Create:
# 1. A Pandas Series from a list of 5 elements
import pandas as pd
data = [10, 20, 30, 40, 50]
series = pd.Series(data)

print("Pandas Series:")
print(series)

# 2. A DataFrame with columns: Name, Department, Salary
data = {
    'Name': ['Aman', 'Riya', 'Rahul', 'Sneha', 'Karan'],
    'Department': ['IT', 'HR', 'IT', 'Finance', 'HR'],
    'Salary': [50000, 60000, 55000, 65000, 52000]
}

df = pd.DataFrame(data)
print("\nDataFrame:")
print(df)

# 3. Write a dataset using (any one): CSV / Excel / JSON
df.to_csv("employee_data.csv", index=False)
# Out:
# Pandas Series:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
#
# DataFrame:
#     Name Department  Salary
# 0   Aman         IT   50000
# 1   Riya         HR   60000
# 2  Rahul         IT   55000
# 3  Sneha    Finance   65000
# 4  Karan         HR   52000

# %% [markdown]
# ## Task 2: Data Exploration (1 Mark)

# %%
# Perform:
# Display first 3 rows
print("First 3 rows:")
print(df.head(3))

# Display dataset information
print("\nDataset Info:")
df.info()

# Display statistical summary
print("\nStatistical Summary:")
print(df.describe())
# Out:
# First 3 rows:
#     Name Department  Salary
# 0   Aman         IT   50000
# 1   Riya         HR   60000
# 2  Rahul         IT   55000
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        5 non-null      object
#  1   Department  5 non-null      object
#  2   Salary      5 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 252.0+ bytes
#
# Statistical Summary:
#              Salary
# count      5.000000
# mean   56400.000000
# std     6107.372594
# min    50000.000000
# 25%    52000.000000
# 50%    55000.000000
# 75%    60000.000000
# max    65000.000000

# %% [markdown]
# ## Task 3: Indexing, Filtering & Sorting (1 Mark)

# %%
# Perform:
# 1. Extract first 3 rows using .loc[]
print("First 3 rows using loc:")
print(df.loc[0:2])

# 2. Extract Salary column using .iloc[]
print("\nSalary column using iloc:")
print(df.iloc[:, 2])

# 3. Filter employees with Salary > 55000
print("\nEmployees with Salary > 55000:")
filtered_df = df[df['Salary'] > 55000]
print(filtered_df)

# 4. Sort dataset by Salary (descending)
print("\nSorted by Salary (Descending):")
sorted_df = df.sort_values(by='Salary', ascending=False)
print(sorted_df)
# Out:
# First 3 rows using loc:
#     Name Department  Salary
# 0   Aman         IT   50000
# 1   Riya         HR   60000
# 2  Rahul         IT   55000
#
# Salary column using iloc:
# 0    50000
# 1    60000
# 2    55000
# 3    65000
# 4    52000
# Name: Salary, dtype: int64
#
# Employees with Salary > 55000:
#     Name Department  Salary
# 1   Riya         HR   60000
# 3  Sneha    Finance   65000
#
# Sorted by Salary (Descending):
#     Name Department  Salary
# 3  Sneha    Finance   65000
# 1   Riya         HR   60000
# 2  Rahul         IT   55000
# 4  Karan         HR   52000
# 0   Aman         IT   50000

# %% [markdown]
# ## Task 4: Group-by & Aggregation (1 Mark)

# %%
# Perform:
# 1. Find average salary department-wise
print("Average Salary Department-wise:")
avg_salary = df.groupby('Department')['Salary'].mean()
print(avg_salary)

# 2. Find total and count of employees per department
print("\nTotal Salary and Employee Count per Department:")
dept_stats = df.groupby('Department')['Salary'].agg(['sum', 'count'])
print(dept_stats)

# %% [markdown]
# ## Task 5: Data Cleaning & Time-Series (1 Mark)

# %%
# Given:
df['Joining_Date'] = ['2022-01-10','2021-07-15','2023-03-12','2020-11-05','2022-05-20']

# Perform:
# 1. Convert Joining_Date to datetime
df['Joining_Date'] = pd.to_datetime(df['Joining_Date'])
print(df.dtypes)

# 2. Extract Year and Month

# 3. Identify duplicate rows
print("\nDuplicate Rows:")
duplicates = df[df.duplicated()]
print(duplicates)

# 4. Remove duplicate rows
df_clean = df.drop_duplicates()

print("\nData after removing duplicates:")
print(df_clean)
# Out:
# Name                    object
# Department              object
# Salary                   int64
# Joining_Date    datetime64[ns]
# dtype: object
#
# Data with Year and Month:
#     Name Department  Salary Joining_Date  Year  Month
# 0   Aman         IT   50000   2022-01-10  2022      1
# 1   Riya         HR   60000   2021-07-15  2021      7
# 2  Rahul         IT   55000   2023-03-12  2023      3
# 3  Sneha    Finance   65000   2020-11-05  2020     11
# 4  Karan         HR   52000   2022-05-20  2022      5
#
# Duplicate Rows:
# Empty DataFrame
# Columns: [Name, Department, Salary, Joining_Date, Year, Month]
# Index: []
#
# Data after removing duplicates:
#     Name Department  Salary Joining_Date  Year  Month
# 0   Aman         IT   50000   2022-01-10  2022      1
# 1   Riya         HR   60000   2021-07-15  2021      7
# 2  Rahul         IT   55000   2023-03-12  2023      3
# 3  Sneha    Finance   65000   2020-11-05  2020     11
# 4  Karan         HR   52000   2022-05-20  2022      5
